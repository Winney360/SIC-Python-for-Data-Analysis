# %%
str = input("Input a string of parentheses: ")
print("Valid" if check(str) else "Invalid")
# Out:
# Input a string of parentheses:  {()}
# Valid

# %%
str = input("Input a string of parentheses: ")
print("Valid" if check(str) else "Invalid")
# Out:
# Input a string of parentheses:  [()]
# Valid

# %%
def check(expr):
    opening = "[(("
    closing = "]))"
    stack = []
    for char in expr:
        if char in opening:
            stack.append(char)
        elif char in closing:
            if len(stack) == 0:
                return False
            if opening.index(stack.pop()) != closing.index(char):
                return False
    return len(stack) == 0

# %%
stack = []
def push(stack, item):
    stack.append(item)
def pop(stack):
    return stack.pop()

# %%
stack = []
print(stack)
push(stack, "A")
print(stack)
push(stack, "B")
print(stack)
pop(stack)
print(stack)
push(stack, "C")
print(stack)
pop(stack)
print(stack)
pop(stack)
print(stack)
# Out:
# []
# ['A']
# ['A', 'B']
# ['A']
# ['A', 'C']
# ['A']
# []

# %%
def is_empty(stack):
    return True if len(stack) == 0 else False

stack = []
print(is_empty(stack))
# Out:
# True

# %%
def pop(stack):
    return None if is_empty(stack) else stack.pop()

stack = []
print(pop(stack))
# Out:
# None

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return True if len(self.stack) == 0 else False

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        return None if self.is_empty() else self.stack.pop()

# %%
stack = Stack()
stack.push("A")
stack.push("B")
print(stack.pop())
stack.push("C")
print(stack.pop())
print(stack.pop())
print(stack.pop())
# Out:
# B
# C
# A
# None

# %%
def peek(stack):
    return None if is_empty(stack) else stack[-1]

# %%
def peek(self):
    return None if is_empty(self.stack) else self.stack[-1]

# %%
str = input("Input a string of parentheses: ")
print("Valid" if check_parentheses(str) else "Invalid")
# Out:
# Input a string of parentheses:  {[]}
# Valid

# %%
def check_parentheses(expr):
    opening = "[(("
    closing = "]))"
    stack = Stack()
    for char in expr:
        if char in opening:
            stack.push(char)
        elif char in closing:
            if stack.is_empty():
                return False
            if opening.index(stack.pop()) != closing.index(char):
                return False
    return stack.is_empty()

# %%
stack = Stack()
stack.push("Banana")
stack.push("Apple")
stack.push("Tomato")
stack.pop()
stack.push("Strawberry")
stack.push("Grapes")
stack.pop()
print(stack.stack)
# Out:
# ['Banana', 'Apple', 'Strawberry']

# %%
stack = Stack()
items = [10 * i for i in range(1, 10)]
for item in items:
    stack.push(item)
    if (item // 10) % 2 == 0:
        stack.pop()
print(stack.stack)
# Out:
# [10, 30, 50, 70, 90]

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return True if len(self.stack) == 0 else False

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        return None if self.is_empty() else self.stack.pop()

    def peek(self):
        return None if self.is_empty() else self.stack[-1]

def check_html_tags(html):
    opening_tags = ["<html>", "<body>", "<h1>", "<p>", "<ul>", "<li>"]
    closing_tags = ["</html>", "</body>", "</h1>", "</p>", "</ul>", "</li>"]
    stack = Stack()
    
    import re
    tags = re.findall(r'<[^>]+>', html)
    
    for tag in tags:
        if tag in opening_tags:
            stack.push(tag)
        elif tag in closing_tags:
            if stack.is_empty():
                return False
            opening_tag = stack.pop()
            if opening_tag.replace("<", "</") != tag:
                return False
    
    return stack.is_empty()

html = """<html>
<body>
<h1>Hello, World!</h1>
<p> We are learning the art of coding with Python programming language. Here we are learning ... </p>
<ul>
<li> Data Structures, </li>
<li> Algorithms, </li>
<li> and Computational Thinking, eventually. </li>
</ul>
</body>
</html>"""

print("Valid" if check_html_tags(html) else "Invalid")
# Out:
# Valid

# %%
def chair_elimination_sequence(n,k):
    sequence = [1,2,3,4,5,6,7]
    queue = []
    for i in range(1, n+1):
        queue.append(i)
        j = 1
        while len(queue) > 1:
            item = queue.pop(0)
            if i % k == 0:
                sequence.append(item)
            else:
                 queue.append(item)
            i += 1
        sequence.append(queue.pop(0))
        return sequence

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) == 0:
            return None
        return self.queue.pop(0)

# %%
queue = Queue()
items = [10 * i for i in range(1, 11)]
for item in items:
    queue.enqueue(item)
    if (item // 10) % 2 == 0:
        queue.dequeue()
print(queue.queue)
# Out:
# [60, 70, 80, 90, 100]

# %%
queue = Queue()
queue.enqueue("A")
queue.enqueue("B")
print(queue.dequeue())
queue.enqueue("C")
print(queue.dequeue())
print(queue.dequeue())
print(queue.dequeue())
# Out:
# A
# B
# C
# None

# %%
class Queue:
    def size(self):
        return len(self.queue)

# %%
def Chair(n, k):
    sequence = []
    queue = Queue()
    for i in range(1, n + 1):
        queue.enqueue(i)
    j = 1
    while queue.size() > 1:
        item = queue.dequeue()
        if j % k == 0:
            sequence.append(item)
        else:
            queue.enqueue(item)
        j += 1
    sequence.append(queue.dequeue())
    return sequence

N = int(input("Input the number of people (N): "))
K = int(input("Input the number to be skipped(K): "))
print(chair_elimination_sequence(N, K))
# Out:
# Input the number of people (N):  3
# Input the number to be skipped(K):  1
# [1, 2, 3, 4, 5, 6, 7, 1]

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) == 0:
            return None
        return self.queue.pop(0)

    def size(self):
        return len(self.queue)

    def is_empty(self):
        return True if len(self.queue) == 0 else False

def Chair(n, k):
    sequence = []
    queue = Queue()
    for i in range(1, n + 1):
        queue.enqueue(i)
    j = 1
    while queue.size() > 1:
        item = queue.dequeue()
        if j % k == 0:
            sequence.append(item)
        else:
            queue.enqueue(item)
        j += 1
    sequence.append(queue.dequeue())
    return sequence

N = int(input("Input the number of people(N): "))
K = int(input("Input the number to be skipped (K): "))
print(Chair(N, K))
# Out:
# Input the number of people(N):  7
# Input the number to be skipped (K):  6
# [6, 5, 7, 2, 1, 4, 3]

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) == 0:
            return None
        return self.queue.pop(0)

queue1 = Queue()
queue1.enqueue("Banana")
queue1.enqueue("Apple")
queue1.enqueue("Tomato")
queue1.dequeue()
queue1.enqueue("Strawberry")
queue1.enqueue("Grapes")
queue1.dequeue()
print(queue1.queue)
# Out:
# ['Tomato', 'Strawberry', 'Grapes']

# %%
queue = Queue()
items = [10 * i for i in range(1, 11)]
for item in items:
    queue.enqueue(item)
    if (item // 10) % 2 == 0:
        queue.dequeue()
print(queue.queue)
# Out:
# [60, 70, 80, 90, 100]

# %%
class Deque:
    def __init__(self):
        self.queue = []

    def add_first(self, item):
        self.queue.insert(0, item)

    def remove_first(self):
        if len(self.queue) == 0:
            return None
        return self.queue.pop(0)

    def add_last(self, item):
        self.queue.append(item)

    def remove_last(self):
        if len(self.queue) == 0:
            return None
        return self.queue.pop()

    def is_empty(self):
        return True if len(self.queue) == 0 else False

    def size(self):
        return len(self.queue)

    def peek_first(self):
        return None if self.is_empty() else self.queue[0]

    def peek_last(self):
        return None if self.is_empty() else self.queue[-1]
# Test the Deque class
deque = Deque()

# Add to front
deque.add_first("C")
deque.add_first("B")
deque.add_first("A")
print(deque.queue) 

# Add to rear
deque.add_last("D")
deque.add_last("E")
print(deque.queue)  

# Remove from front
print(deque.remove_first())  
print(deque.queue)  

# Remove from rear
print(deque.remove_last())  
print(deque.queue) 

# Check size and empty
print(deque.size())  
print(deque.is_empty())  

# Peek without removing
print(deque.peek_first()) 
print(deque.peek_last())  
print(deque.queue)
# Out:
# ['A', 'B', 'C']
# ['A', 'B', 'C', 'D', 'E']
# A
# ['B', 'C', 'D', 'E']
# E
# ['B', 'C', 'D']
# 3
# False
# B
# D
# ['B', 'C', 'D']

# %%
text = input("input the string of HTML documment")
start = text.fib

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return True if len(self.stack) == 0 else False

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        return None if self.is_empty() else self.stack.pop()

    def peek(self):
        return None if self.is_empty() else self.stack[-1]

def check_html_tags(html):
    stack = Stack()
    
    # Find all tags using the method described in the notes
    tags = []
    start = html.find('<')
    
    while start != -1:
        end = html.find('>', start + 1)
        if end == -1:
            break
        tag = html[start:end+1]
        tags.append(tag)
        start = html.find('<', end + 1)
    
    # Check tag matching using stack (similar to parenthesis matching)
    for tag in tags:
        # Check if it's a closing tag (contains '/')
        if '/' in tag:
            # It's a closing tag
            if stack.is_empty():
                return False
            opening_tag = stack.pop()
            # Check if closing tag matches the opening tag
            # e.g., opening '<html>' matches closing '</html>'
            if opening_tag[1:-1] != tag[2:-1]:
                return False
        else:
            # It's an opening tag
            stack.push(tag)
    
    # Stack should be empty if all tags are properly matched
    return stack.is_empty()

# Input string from the example
text =  """<html>
<body>
<h1>Hello, World!</h1>
<p> We are learning the art of coding with Python programming language. Here we are learning ... </p>
<ul>
<li> Data Structures, </li>
<li> Algorithms, </li>
<li> and Computational Thinking, eventually. </li>
</ul>
</body>
</html>"""

# Test the function
print("Valid" if check_html_tags(text) else "Invalid")
# Out:
# Valid

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def is_empty(self):
        return True if len(self.stack) == 0 else False

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        return None if self.is_empty() else self.stack.pop()

    def peek(self):
        return None if self.is_empty() else self.stack[-1]

def check_html_tags(html):
    stack = Stack()
    
    # Find all tags using the method described in the notes
    tags = []
    start = html.find('<')
    
    while start != -1:
        end = html.find('>', start + 1)
        if end == -1:
            break
        tag = html[start:end+1]
        tags.append(tag)
        start = html.find('<', end + 1)
    
    # Check tag matching using stack (similar to parenthesis matching)
    for tag in tags:
        # Check if it's a closing tag (contains '/')
        if '/' in tag:
            # It's a closing tag
            if stack.is_empty():
                return False
            opening_tag = stack.pop()
            # Check if closing tag matches the opening tag
            # e.g., opening '<html>' matches closing '</html>'
            if opening_tag[1:-1] != tag[2:-1]:
                return False
        else:
            # It's an opening tag
            stack.push(tag)
    
    # Stack should be empty if all tags are properly matched
    return stack.is_empty()

# Get input from user
text = input("Input the string of HTML document: ")

# Test the function
print("Valid" if check_html_tags(text) else "Invalid")
# Out:
# Input the string of HTML document:  <html> <body> <h1>Hello, World!</h1> <p> We are learning the art of coding with Python programming language. Here we are learning ... </p> <ul> <li> Data Structures, </li> <li> Algorithms, </li> <li> and Computational Thinking, eventually. </li> </ul> </body> </html>
# Valid

# %%
def do_experiment(floor, breaking):
    return floor>= breaking

def find_highest_safe_floor(height,breaking):
    for n in range(1, height + 1):
        if do_experiment(n, breaking):
            return n-1
    return height

from random import randint

height = int(input("Input the number of floors: "))
breaking = randint(1, height)
floor = find_highest_safe_floor(height, breaking)
print(f"Your egg will be safe till the {floor}-th floor.")
# Out:
# Input the number of floors:  100
# Your egg will be safe till the 12-th floor.

# %%
S = [11,37, 45, 26, 59, 28, 17, 53]
x = 11
pos = seq_search(S,x)
print(f"In S, {x} is at position {pos}.")

def seq_search(nums, x):
    for i in range(len(nums)):
        if x == nums[i]:
            return i
    return -1
# Out:
# In S, 11 is at position 0.

# %%
def find_largest(nums):
    largest = 0
    for i in range(1, len(nums)):
        if nums[largest] < nums[i]:
            largest = i
    return largest

nums = [11, 37, 45, 26, 28, 17, 53]
pos =  find_largest(nums)
print(f"The largest is {num[pos]} at {pos}")
# Out:
# The largest is 53 at 6

# %%
def find_two(nums):
    x = y = 0
    for i in range(1, len(nums)):
        if nums[x] < nums[i]:
            x = i
        elif nums[y] > nums[i]:
            y = i
    return x, y

nums = [11, 37, 45, 26, 59, 28, 17, 53]
i,j = find_two(nums)
print(nums[i], nums[j])
# Out:
# 59 11

# %%
def word_count(S, x):
    count = 0
    for word in S:
        if word == x:
            count += 1
    return count
        

S = list(input("Input a sentence: ").split())
x = input("Input a word to search:")
count = word_count(S, x)
print(f"In the sentence , {x} is appeared in {count} times." )
# Out:
# Input a sentence:  I am very very very happy
# Input a word to search: very
# In the sentence , very is appeared in 3 times.

# %%
def bin_search(nums, x):
    low,high = 0 , len(nums) - 1
    while low <= high:
        mid = (low + high) //2
        if num[mid] == x:
            return mid
        elif num[mid] == x:
            high = mid - 1
        else:
            low = mid + 1
    return -1

nums = [11, 17, 26, 28, 37,45, 53, 59]
x = int(input("Input the number to search: "))
pos = bin_search(nums,x)
print(f"In S , {x} is at position {pos}.")
# Out:
# Input the number to search:  53
# In S , 53 is at position 6.

# %%
def roman_to_int(str):
    result = 0
    for i in range(len(str) - 1):
        if table[str[i]] < table[str[i + 1]]:
            result -= table[str[i]]
        else:
            result += table[str[i]]
    return result + table[str[-1]]

table = {'I':1, 'V':5, 'X':10, 'L':50, 'C':100, 'D':500, 'M':1000}
roman = input("Input a roman number")
number = roman_to_int(roman)
print(number)
# Out:
# Input a roman number IV
# 4
