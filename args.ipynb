# %%
def display_students(*students):
    print("The last student is" , students[3])
def main():
    display_students("Jane", "Job", "Bob", "Tom")
if __name__ == "__main__":
    main()
# Out:
# The last student is Tom
